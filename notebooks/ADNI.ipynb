# %%
import sys
sys.path.append('..')

from src.adni.adni import quickADNI, plot_result_dict

# %%
#Arguments to be set for the ADNI experiments
#set_path - Path to the ADNIMERGE dataset
#task - Either 'MMSE' or 'AD'
#priv_points - Either 1 or 3
#nan_threshold - default 0.7 as in article
#seed - default 42 as in article

ADNIMERGE_path = ''

# %% [markdown]
# ### MMSE 1 privileged time point

# %%
task = 'MMSE'
priv_points = 1
result = quickADNI(ADNIMERGE_path, task, priv_points)
fig = plot_result_dict(result, '$R^2$ score', '')
# Out:
# C:\Users\marti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (18,19,20,103,104) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# MMSE
# Number of subjects: 502

# %% [markdown]
# ### MMSE 3 privileged time points

# %%
task = 'MMSE'
priv_points = 3
result = quickADNI(ADNIMERGE_path, task, priv_points)
fig = plot_result_dict(result, '$R^2$ score', '')
# Out:
# c:\users\martin\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,19,20,103,104) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# MMSE
# Number of subjects: 502

# %% [markdown]
# ### AD 1 privieged time point

# %%
task = 'AD'
priv_points = 1
result = quickADNI(ADNIMERGE_path, task, priv_points)
fig = plot_result_dict(result, 'AUC', '')
# Out:
# c:\users\martin\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,19,20,103,104) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# AD
# Number of subjects: 504
# Number of positives at last time step: 133
# Number of negatives at last time step: 371

# %% [markdown]
# ### AD 3 privileged time points

# %%
task = 'AD'
priv_points = 3
result = quickADNI(ADNIMERGE_path, task, priv_points)
fig = plot_result_dict(result, 'AUC', '')
# Out:
# c:\users\martin\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (18,19,20,103,104) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# AD
# Number of subjects: 504
# Number of positives at last time step: 133
# Number of negatives at last time step: 371
